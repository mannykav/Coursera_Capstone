# %% [markdown]
# # Georgia and Florida Reopening Among COVID-19 Concerns

# %% [markdown]
# ## Applied Data Science Capstone by IBM/Coursera

# %% [markdown]
# ## Introduction/Business Problem
# There are cities like Jacksonville reopening beaches while Georgia is planning to reopen several businesses starting April 24th. Is this a good time to consider reopening with the risk to public health from  COVID-19 or will there be too much economic damage if not? In order to answer the questions, I will take a look at county health population information from https://www.countyhealthrankings.org/ and business information(leveraging Foursquare API)in Jacksonsville, Florida and compare to Savannah, Georgia since they are large cities located in the neighboring states. The governers of Georgia and Florida should take these factors into consideration before opening their states among COVID-19.

# %% [markdown]
# ## Data
# <b>I.Foursquare Location API</b> <br>
# I will explore business information such as number and type of businesses to see the type of impact closing the cities will have. I also want to see if there are nearby clinics, hospitals, and/or pharmacies to learn about capacity for handling rise in cases for decision in reopening.
#
# <b>II.County Health Rankings</b> <br>
# I will be using county health rankings to get detailed information about the population using information such as:
# - Quality of Life
# - Health Behaviors
# - Clinical Care
# - Social & Economic Factors

# %% [markdown]
# Code follows:

# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

# !conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans



print('Libraries imported.')

# %%
# !conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - folium=0.5.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     altair-4.1.0               |             py_1         614 KB  conda-forge
#     folium-0.5.0               |             py_0          45 KB  conda-forge
#     branca-0.4.0               |             py_0          26 KB  conda-forge
#     vincent-0.4.4              |             py_1          28 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         713 KB
#
# The following NEW packages will be INSTALLED:
#
#     altair:  4.1.0-py_1 conda-forge
#     branca:  0.4.0-py_0 conda-forge
#     folium:  0.5.0-py_0 conda-forge
#     vincent: 0.4.4-py_1 conda-forge
#
#
# Downloading and Extracting Packages
# altair-4.1.0         | 614 KB    | ##################################### | 100%
# folium-0.5.0         | 45 KB     | ##################################### | 100%
# branca-0.4.0         | 26 KB     | ##################################### | 100%
# vincent-0.4.4        | 28 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %%
CLIENT_ID = 'KTOGVYYQUEWMCLZYN3EHY3W1FJ2EUDJ1FIXZKSXQCWBXNQJA' # your Foursquare ID
CLIENT_SECRET = '01RRALCQSNM3UZKYRWZYBNMJL5O5TBFCCBRVKYI4XUA0MSWW' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 30
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: KTOGVYYQUEWMCLZYN3EHY3W1FJ2EUDJ1FIXZKSXQCWBXNQJA
# CLIENT_SECRET:01RRALCQSNM3UZKYRWZYBNMJL5O5TBFCCBRVKYI4XUA0MSWW

# %%
address = 'Savannah,Georgia'

geolocator = Nominatim(user_agent="to_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of {} are {}, {}.'.format(address,latitude, longitude))
# Out:
# The geograpical coordinate of Savannah,Georgia are 32.0809263, -81.0911768.

# %%
# define the dataframe columns
column_names = ['Borough', 'Neighborhood', 'Latitude', 'Longitude'] 

# instantiate the dataframe
neighborhoods = pd.DataFrame(columns=column_names)
neighborhoods
# Out:
# Empty DataFrame
# Columns: [Borough, Neighborhood, Latitude, Longitude]
# Index: []

# %%
jk_df = {'City': ['Jacksonville','Cocoa Beach','Daytona Beach','Savannah'],
        'State': ['Florida','Florida','Florida','Georgia'],
        'Latitude':['30.3321838','28.3200','29.2108','32.0809263'],
        'Longitude':['-81.655651','-80.6076','-81.0228','-81.0911768']
        }

jk_df = pd.DataFrame(jk_df, columns = ['City', 'State','Latitude','Longitude'])

print (jk_df)
# Out:
#             City    State    Latitude    Longitude
# 0   Jacksonville  Florida  30.3321838   -81.655651
# 1    Cocoa Beach  Florida     28.3200     -80.6076
# 2  Daytona Beach  Florida     29.2108     -81.0228
# 3       Savannah  Georgia  32.0809263  -81.0911768

# %%
city_latitude = jk_df.loc[0, 'Latitude'] # neighborhood latitude value
city_longitude = jk_df.loc[0, 'Longitude'] # neighborhood longitude value

city_name = jk_df.loc[0, 'City'] # neighborhood name

print('Latitude and longitude values of {} are {}, {}.'.format(city_name, 
                                                               city_latitude, 
                                                               city_longitude))
# Out:
# Latitude and longitude values of Jacksonville are 30.3321838, -81.655651.

# %%
city_latitude = jk_df.loc[1, 'Latitude'] # neighborhood latitude value
city_longitude = jk_df.loc[1, 'Longitude'] # neighborhood longitude value

city_name = jk_df.loc[1, 'City'] # neighborhood name

print('Latitude and longitude values of {} are {}, {}.'.format(city_name, 
                                                               city_latitude, 
                                                               city_longitude))
# Out:
# Latitude and longitude values of Cocoa Beach are 28.3200, -80.6076.

# %%
city_latitude = jk_df.loc[2, 'Latitude'] # neighborhood latitude value
city_longitude = jk_df.loc[2, 'Longitude'] # neighborhood longitude value

city_name = jk_df.loc[2, 'City'] # neighborhood name

print('Latitude and longitude values of {} are {}, {}.'.format(city_name, 
                                                               city_latitude, 
                                                               city_longitude))
# Out:
# Latitude and longitude values of Daytona Beach are 29.2108, -81.0228.

# %%
city_latitude = jk_df.loc[3, 'Latitude'] # neighborhood latitude value
city_longitude = jk_df.loc[3, 'Longitude'] # neighborhood longitude value

city_name = jk_df.loc[3, 'City'] # neighborhood name

print('Latitude and longitude values of {} are {}, {}.'.format(city_name, 
                                                               city_latitude, 
                                                               city_longitude))
# Out:
# Latitude and longitude values of Savannah are 32.0809263, -81.0911768.

# %%
LIMIT = 100 # limit of number of venues returned by Foursquare API

radius = 500 # define radius

# create URL
url2 = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    city_latitude, 
    city_longitude, 
    radius, 
    LIMIT)
url2 # display URL
# Out:
# 'https://api.foursquare.com/v2/venues/explore?&client_id=KTOGVYYQUEWMCLZYN3EHY3W1FJ2EUDJ1FIXZKSXQCWBXNQJA&client_secret=01RRALCQSNM3UZKYRWZYBNMJL5O5TBFCCBRVKYI4XUA0MSWW&v=20180604&ll=32.0809263,-81.0911768&radius=500&limit=100'

# %%
results = requests.get(url2).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5ea24e220cc1fd001bc783f4'},
#  'response': {'suggestedFilters': {'header': 'Tap to show:',
#    'filters': [{'name': '$-$$$$', 'key': 'price'},
#     {'name': 'Open now', 'key': 'openNow'}]},
#   'headerLocation': 'Historic District-North',
#   'headerFullLocation': 'Historic District-North, Savannah',
#   'headerLocationGranularity': 'neighborhood',
#   'totalResults': 55,
#   'suggestedBounds': {'ne': {'lat': 32.085426304500004,
#     'lng': -81.08587571542196},
#    'sw': {'lat': 32.0764262955, 'lng': -81.09647788457804}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d63d214dd51ba7a7b30ba02',
#        'name': 'Savannah Bee Company',
#        'location': {'address': '1 W River St',
#         'lat': 32.08167968720722,
#         'lng': -81.09118353022185,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 32.08167968720722,
#           'lng': -81.09118353022185}],
#         'distance': 83,
#         'postalCode': '31401',
#         'cc': 'US',
#         'city': 'Savannah',
#         'state': 'GA',
#         'country': 'United States',
#         'formattedAddress': ['1 W River St',
#          'Savannah, GA 31401',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1f5941735',
#          'name': 'Gourmet Shop',
#          'pluralName': 'Gourmet Shops',
#          'shortName': 'Gourmet',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_gourmet_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d63d214dd51ba7a7b30ba02-0'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '56855feb38fabef80c08554e',
#        'name': 'Cafe M',
#        'location': {'address': '128 E Bay St',
#         'lat': 32.0806784241718,
#         'lng': -81.08915248874575,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 32.0806784241718,
#           'lng': -81.08915248874575},
#          {'label': '?', 'lat': 32.0815, 'lng': -81.090882}],
#         'distance': 192,
#         'postalCode': '31401',
#         'cc': 'US',
#         'city': 'Savannah',
#         'state': 'GA',
#         'country': 'United States',
#         'formattedAddress': ['128 E Bay St',
#          'Savannah, GA 31401',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '350324411'}},
#       'referralId': 'e-0-56855feb38fabef80c08554e-1'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b53964df964a5208aa327e3',
#        'name': 'River Street Sweets',
#        'location': {'address': '13 E River St',
#         'lat': 32.081494424012966,
#         'lng': -81.09044215248989,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 32.081494424012966,
#           'lng': -81.09044215248989},
#          {'label': '?', 'lat': 32.08085, 'lng': -81.088863}],
#         'distance': 93,
#         'postalCode': '31401',
#         'cc': 'US',
#         'city': 'Savannah',
#         'state': 'GA',
#         'country': 'United States',
#         'formattedAddress': ['13 E River St',
#          'Savannah, GA 31401',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d117951735',
#          'name': 'Candy Store',
#          'pluralName': 'Candy Stores',
#          'shortName': 'Candy Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/candystore_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b53964df964a5208aa327e3-2'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '54483ad7498e170fd9863522',
#        'name': 'Treylor Park Restaurant & Biergarten',
#        'location': {'address': '115 Bay St',
#         'lat': 32.080518576671565,
#         'lng': -81.08969790841616,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 32.080518576671565,
#           'lng': -81.08969790841616}],
#         'distance': 146,
#         'postalCode': '31401',
#         'cc': 'US',
#         'city': 'Savannah',
#         'state': 'GA',
#         'country': 'United States',
#         'formattedAddress': ['115 Bay St',
#          'Savannah, GA 31401',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1c4941735',
#          'name': 'Restaurant',
#          'pluralName': 'Restaurants',
#          'shortName': 'Restaurant',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-54483ad7498e170fd9863522-3'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '59d27c4c2105c3413dc411f6',
#        'name': 'Little Duck Diner',
#        'location': {'address': '150 W Saint Julian Street',
#         'lat': 32.08046628598283,
#         'lng': -81.09317834424527,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 32.08046628598283,
#           'lng': -81.09317834424527}],
#         'distance': 195,
#         'postalCode': '31401',
#         'cc': 'US',
#         'city': 'Savannah',
#         'state': 'GA',
#         'country': 'United States',
#         'formattedAddress': ['150 W Saint Julian Street',
#          'Savannah, GA 31401',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d147941735',
#          'name': 'Diner',
#          'pluralName': 'Diners',
#          'shortName': 'Diner',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/diner_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-59d27c4c2105c3413dc411f6-4'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cd166e37b68548135cec6f8',
#        'name': 'World War II Monument & Memorial',
#        'location': {'lat': 32.08207750850833,
#         'lng': -81.09216152511256,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 32.08207750850833,
#           'lng': -81.09216152511256}],
#         'distance': 158,
#         'postalCode': '31401',
#         'cc': 'US',
#         'city': 'Savannah',
#         'state': 'GA',
#         'country': 'United States',
#         'formattedAddress': ['Savannah, GA 31401', 'United States']},
#        'categories': [{'id': '4bf58dd8d48988d164941735',
#          'name': 'Plaza',
#          'pluralName': 'Plazas',
#          'shortName': 'Plaza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/plaza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4cd166e37b68548135cec6f8-5'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ceff1927b943704cc163653',
#        'name': 'Your Pie',
#        'location': {'address': '110 West Bryan Street',
#         'crossStreet': 'at Whitaker St',
#         'lat': 32.080649,
#         'lng': -81.092687,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 32.080649,
#           'lng': -81.092687},
#          {'label': '?', 'lat': 32.080688, 'lng': -81.09301}],
#         'distance': 145,
#         'postalCode': '31401',
#         'cc': 'US',
#         'city': 'Savannah',
#         'state': 'GA',
#         'country': 'United States',
#         'formattedAddress': ['110 West Bryan Street (at Whitaker St)',
#          'Savannah, GA 31401',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1ca941735',
#          'name': 'Pizza Place',
#          'pluralName': 'Pizza Places',
#          'shortName': 'Pizza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ceff1927b943704cc163653-6'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b1075ebf964a520ec7023e3',
#        'name': 'Olde Pink House Restaurant',
#        'location': {'address': '23 Abercorn St',
#         'crossStreet': 'btw Bryan & St Julian',
#         'lat': 32.07955,
#         'lng': -81.08973,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 32.07955,
#           'lng': -81.08973},
#          {'label': '?', 'lat': 32.079605, 'lng': -81.089764}],
#         'distance': 205,
#         'postalCode': '31401',
#         'cc': 'US',
#         'city': 'Savannah',
#         'state': 'GA',
#         'country': 'United States',
#         'formattedAddress': ['23 Abercorn St (btw Bryan & St Julian)',
#          'Savannah, GA 31401',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d14f941735',
#          'name': 'Southern / Soul Food Restaurant',
#          'pluralName': 'Southern / Soul Food Restaurants',
#          'shortName': 'Southern / Soul',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/southern_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b1075ebf964a520ec7023e3-7'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ad09498f964a5208ed820e3',
#        'name': "Vic's On The River",
#        'location': {'address': '26 E Bay St',
#         'lat': 32.08124141636196,
#         'lng': -81.09033892400038,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 32.08124141636196,
#           'lng': -81.09033892400038},
#          {'label': '?', 'lat': 32.081398, 'lng': -81.090919}],
#         'distance': 86,
#         'postalCode': '31401',
#         'cc': 'US',
#         'city': 'Savannah',
#         'state': 'GA',
#         'country': 'United States',
#         'formattedAddress': ['26 E Bay St',
#          'Savannah, GA 31401',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d14f941735',
#          'name': 'Southern / Soul Food Restaurant',
#          'pluralName': 'Southern / Soul Food Restaurants',
#          'shortName': 'Southern / Soul',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/southern_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ad09498f964a5208ed820e3-8'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '51acd61aabd81fd380f1629c',
#        'name': 'Chive Sea Bar + Lounge',
#        'location': {'address': '4 W Broughton St',
#         'crossStreet': 'Bull street & Broughton Street',
#         'lat': 32.07901242799201,
#         'lng': -81.09221774563292,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 32.07901242799201,
#           'lng': -81.09221774563292},
#          {'label': '?', 'lat': 32.07912, 'lng': -81.092244}],
#         'distance': 234,
#         'postalCode': '31401',
#         'cc': 'US',
#         'city': 'Savannah',
#         'state': 'GA',
#         'country': 'United States',
#         'formattedAddress': ['4 W Broughton St (Bull street & Broughton Street)',
#          'Savannah, GA 31401',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d121941735',
#          'name': 'Lounge',
#          'pluralName': 'Lounges',
#          'shortName': 'Lounge',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-51acd61aabd81fd380f1629c-9'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b522d86f964a520be6d27e3',
#        'name': 'Savannah Bee Company',
#        'location': {'address': '104 W Broughton St',
#         'lat': 32.07936425940897,
#         'lng': -81.09321601924417,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 32.07936425940897,
#           'lng': -81.09321601924417},
#          {'label': '?', 'lat': 32.079393, 'lng': -81.093281}],
#         'distance': 259,
#         'postalCode': '31401',
#         'cc': 'US',
#         'city': 'Savannah',
#         'state': 'GA',
#         'country': 'United States',
#         'formattedAddress': ['104 W Broughton St',
#          'Savannah, GA 31401',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1f5941735',
#          'name': 'Gourmet Shop',
#          'pluralName': 'Gourmet Shops',
#          'shortName': 'Gourmet',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_gourmet_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b522d86f964a520be6d27e3-10'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c2bc5a7b34ad13a4752eace',
#        'name': "Ruth's Chris Steak House",
#        'location': {'address': '111 W Bay St',
#         'crossStreet': 'at the corner of Bay & Whitaker St.',
#         'lat': 32.081109862630726,
#         'lng': -81.0925488173961,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 32.081109862630726,
#           'lng': -81.0925488173961}],
#         'distance': 131,
#         'postalCode': '31401',
#         'cc': 'US',
#         'city': 'Savannah',
#         'state': 'GA',
#         'country': 'United States',
#         'formattedAddress': ['111 W Bay St (at the corner of Bay & Whitaker St.)',
#          'Savannah, GA 31401',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1cc941735',
#          'name': 'Steakhouse',
#          'pluralName': 'Steakhouses',
#          'shortName': 'Steakhouse',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/steakhouse_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '2057499',
#         'url': 'https://www.grubhub.com/restaurant/ruths-chris-steakhouse-111-w-bay-st-savannah/2057499?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2057499',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c2bc5a7b34ad13a4752eace-11'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b3678cff964a5203e3625e3',
#        'name': 'Andaz Savannah - a concept by Hyatt',
#        'location': {'address': '14 Barnard St',
#         'lat': 32.08079373194261,
#         'lng': -81.09342633180103,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 32.08079373194261,
#           'lng': -81.09342633180103},
#          {'label': '?', 'lat': 32.081, 'lng': -81.093505}],
#         'distance': 212,
#         'postalCode': '31401',
#         'cc': 'US',
#         'city': 'Savannah',
#         'state': 'GA',
#         'country': 'United States',
#         'formattedAddress': ['14 Barnard St',
#          'Savannah, GA 31401',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b3678cff964a5203e3625e3-12'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b1bd110f964a520b0fd23e3',
#        'name': 'Reynolds Square',
#        'location': {'address': 'E Congress St',
#         'crossStreet': 'at Abercorn St',
#         'lat': 32.07932536630871,
#         'lng': -81.08935469101534,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 32.07932536630871,
#           'lng': -81.08935469101534}],
#         'distance': 247,
#         'postalCode': '31401',
#         'cc': 'US',
#         'city': 'Savannah',
#         'state': 'GA',
#         'country': 'United States',
#         'formattedAddress': ['E Congress St (at Abercorn St)',
#          'Savannah, GA 31401',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d163941735',
#          'name': 'Park',
#          'pluralName': 'Parks',
#          'shortName': 'Park',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b1bd110f964a520b0fd23e3-13'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '50784378e4b0459b7580fba5',
#        'name': 'The Coffee Fox',
#        'location': {'address': '102 W Broughton St',
#         'crossStreet': 'at Whitaker St',
#         'lat': 32.07931236594066,
#         'lng': -81.09314444882843,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 32.07931236594066,
#           'lng': -81.09314444882843},
#          {'label': '?', 'lat': 32.07937, 'lng': -81.093187}],
#         'distance': 258,
#         'postalCode': '31401',
#         'cc': 'US',
#         'neighborhood': 'Historic District-North',
#         'city': 'Savannah',
#         'state': 'GA',
#         'country': 'United States',
#         'formattedAddress': ['102 W Broughton St (at Whitaker St)',
#          'Savannah, GA 31401',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-50784378e4b0459b7580fba5-14'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b523ec3f964a5204e7227e3',
#        'name': 'The Paris Market & Brocante',
#        'location': {'address': '36 W Broughton St',
#         'crossStreet': 'btwn Whitaker & Bull St.',
#         'lat': 32.079344419996914,
#         'lng': -81.09299865837383,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 32.079344419996914,
#           'lng': -81.09299865837383}],
#         'distance': 246,
#         'postalCode': '31401',
#         'cc': 'US',
#         'city': 'Savannah',
#         'state': 'GA',
#         'country': 'United States',
#         'formattedAddress': ['36 W Broughton St (btwn Whitaker & Bull St.)',
#          'Savannah, GA 31401',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d104951735',
#          'name': 'Boutique',
#          'pluralName': 'Boutiques',
#          'shortName': 'Boutique',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_boutique_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b523ec3f964a5204e7227e3-15'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '51bf80dc498e3452ffc54907',
#        'name': 'Savannah Riverfront',
#        'location': {'address': 'E. River Street',
#         'lat': 32.080989,
#         'lng': -81.088147,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 32.080989,
#           'lng': -81.088147}],
#         'distance': 285,
#         'postalCode': '31401',
#         'cc': 'US',
#         'city': 'Savannah',
#         'state': 'GA',
#         'country': 'United States',
#         'formattedAddress': ['E. River Street',
#          'Savannah, GA 31401',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0941735',
#          'name': 'Harbor / Marina',
#          'pluralName': 'Harbors / Marinas',
#          'shortName': 'Harbor / Marina',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/harbor_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-51bf80dc498e3452ffc54907-16'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '52b63c09498ee09251643e22',
#        'name': 'Persepolis',
#        'location': {'address': '41 Whitaker St',
#         'lat': 32.079587,
#         'lng': -81.09354300000001,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 32.079587,
#           'lng': -81.09354300000001}],
#         'distance': 268,
#         'cc': 'US',
#         'city': 'Savannah',
#         'state': 'GA',
#         'country': 'United States',
#         'formattedAddress': ['41 Whitaker St',
#          'Savannah, GA',
#          'United States']},
#        'categories': [{'id': '52e81612bcbc57f1066b79f7',
#          'name': 'Persian Restaurant',
#          'pluralName': 'Persian Restaurants',
#          'shortName': 'Persian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/middleeastern_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-52b63c09498ee09251643e22-17'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b61c009f964a5206e202ae3',
#        'name': 'Ellis Square',
#        'location': {'address': 'Barnard St',
#         'crossStreet': 'btwn Bryan St & Congress St',
#         'lat': 32.08057528381516,
#         'lng': -81.09388772068003,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 32.08057528381516,
#           'lng': -81.09388772068003}],
#         'distance': 258,
#         'postalCode': '31401',
#         'cc': 'US',
#         'city': 'Savannah',
#         'state': 'GA',
#         'country': 'United States',
#         'formattedAddress': ['Barnard St (btwn Bryan St & Congress St)',
#          'Savannah, GA 31401',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d164941735',
#          'name': 'Plaza',
#          'pluralName': 'Plazas',
#          'shortName': 'Plaza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/plaza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b61c009f964a5206e202ae3-18'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5734fa04498e142ffba506ea',
#        'name': 'Hampton Inn by Hilton',
#        'location': {'address': '201 E Bay St',
#         'lat': 32.0801548,
#         'lng': -81.0888674,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 32.0801548,
#           'lng': -81.0888674},
#          {'label': '?', 'lat': 32.080823, 'lng': -81.088241}],
#         'distance': 234,
#         'postalCode': '31401',
#         'cc': 'US',
#         'city': 'Savannah',
#         'state': 'GA',
#         'country': 'United States',
#         'formattedAddress': ['201 E Bay St',
#          'Savannah, GA 31401',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5734fa04498e142ffba506ea-19'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b53504af964a520d69627e3',
#        'name': 'Bayou Cafe',
#        'location': {'address': '14 N Abercorn St',
#         'crossStreet': 'River St.',
#         'lat': 32.08086044289941,
#         'lng': -81.08870108303785,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 32.08086044289941,
#           'lng': -81.08870108303785}],
#         'distance': 233,
#         'postalCode': '31401',
#         'cc': 'US',
#         'city': 'Savannah',
#         'state': 'GA',
#         'country': 'United States',
#         'formattedAddress': ['14 N Abercorn St (River St.)',
#          'Savannah, GA 31401',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d118941735',
#          'name': 'Dive Bar',
#          'pluralName': 'Dive Bars',
#          'shortName': 'Dive Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/divebar_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b53504af964a520d69627e3-20'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bef4508d1b7d13aa496cdec',
#        'name': "Savannah's Candy Kitchen",
#        'location': {'address': '225 E River St',
#         'lat': 32.08078108364155,
#         'lng': -81.08787347586103,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 32.08078108364155,
#           'lng': -81.08787347586103},
#          {'label': '?', 'lat': 32.080709, 'lng': -81.087757}],
#         'distance': 311,
#         'postalCode': '31401',
#         'cc': 'US',
#         'city': 'Savannah',
#         'state': 'GA',
#         'country': 'United States',
#         'formattedAddress': ['225 E River St',
#          'Savannah, GA 31401',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d117951735',
#          'name': 'Candy Store',
#          'pluralName': 'Candy Stores',
#          'shortName': 'Candy Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/candystore_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bef4508d1b7d13aa496cdec-21'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '578e697e498edc7a3f49db36',
#        'name': 'Savannah Seafood Shack',
#        'location': {'lat': 32.07857984089961,
#         'lng': -81.09027659883446,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 32.07857984089961,
#           'lng': -81.09027659883446},
#          {'label': '?', 'lat': 32.078583, 'lng': -81.090173}],
#         'distance': 274,
#         'postalCode': '31401',
#         'cc': 'US',
#         'city': 'Savannah',
#         'state': 'GA',
#         'country': 'United States',
#         'formattedAddress': ['Savannah, GA 31401', 'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1ce941735',
#          'name': 'Seafood Restaurant',
#          'pluralName': 'Seafood Restaurants',
#          'shortName': 'Seafood',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/seafood_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-578e697e498edc7a3f49db36-22'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bcf248bb221c9b6d864d1d0',
#        'name': 'Soda Pop Shop',
#        'location': {'address': '114 Bull St',
#         'lat': 32.07839937891539,
#         'lng': -81.09215591491527,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 32.07839937891539,
#           'lng': -81.09215591491527},
#          {'label': '?', 'lat': 32.078422, 'lng': -81.092004}],
#         'distance': 296,
#         'postalCode': '31401',
#         'cc': 'US',
#         'city': 'Savannah',
#         'state': 'GA',
#         'country': 'United States',
#         'formattedAddress': ['114 Bull St',
#          'Savannah, GA 31401',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d117951735',
#          'name': 'Candy Store',
#          'pluralName': 'Candy Stores',
#          'shortName': 'Candy Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/candystore_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bcf248bb221c9b6d864d1d0-23'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '55fa0de6498e6e88f47654d4',
#        'name': 'Bella Napoli Italian Bistro',
#        'location': {'address': '18 E State St',
#         'lat': 32.078112848585896,
#         'lng': -81.091525655264,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 32.078112848585896,
#           'lng': -81.091525655264}],
#         'distance': 314,
#         'postalCode': '31401',
#         'cc': 'US',
#         'city': 'Savannah',
#         'state': 'GA',
#         'country': 'United States',
#         'formattedAddress': ['18 E State St',
#          'Savannah, GA 31401',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-55fa0de6498e6e88f47654d4-24'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b1c018df964a520990024e3',
#        'name': "Leopold's Ice Cream",
#        'location': {'address': '212 E Broughton St',
#         'lat': 32.07835412246888,
#         'lng': -81.08949336847391,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 32.07835412246888,
#           'lng': -81.08949336847391},
#          {'label': '?', 'lat': 32.078259, 'lng': -81.088931}],
#         'distance': 327,
#         'postalCode': '31401',
#         'cc': 'US',
#         'city': 'Savannah',
#         'state': 'GA',
#         'country': 'United States',
#         'formattedAddress': ['212 E Broughton St',
#          'Savannah, GA 31401',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1c9941735',
#          'name': 'Ice Cream Shop',
#          'pluralName': 'Ice Cream Shops',
#          'shortName': 'Ice Cream',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/icecream_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b1c018df964a520990024e3-25'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '51c7927f498edf953cdd55d0',
#        'name': "Tequila's Town Mexican Restaurant",
#        'location': {'address': '109 Whitaker St',
#         'lat': 32.07880779371858,
#         'lng': -81.09327121849304,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 32.07880779371858,
#           'lng': -81.09327121849304},
#          {'label': '?', 'lat': 32.07878, 'lng': -81.093306}],
#         'distance': 307,
#         'postalCode': '31401',
#         'cc': 'US',
#         'city': 'Savannah',
#         'state': 'GA',
#         'country': 'United States',
#         'formattedAddress': ['109 Whitaker St',
#          'Savannah, GA 31401',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1c1941735',
#          'name': 'Mexican Restaurant',
#          'pluralName': 'Mexican Restaurants',
#          'shortName': 'Mexican',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mexican_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-51c7927f498edf953cdd55d0-26'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4babaa1df964a52034be3ae3',
#        'name': 'Nourish',
#        'location': {'address': 'Broughton',
#         'crossStreet': 'Barnard St.',
#         'lat': 32.0796235456431,
#         'lng': -81.0942494756933,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 32.0796235456431,
#           'lng': -81.0942494756933},
#          {'label': '?', 'lat': 32.079675, 'lng': -81.09434}],
#         'distance': 324,
#         'cc': 'US',
#         'city': 'Savannah',
#         'state': 'GA',
#         'country': 'United States',
#         'formattedAddress': ['Broughton (Barnard St.)',
#          'Savannah, GA',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d10c951735',
#          'name': 'Cosmetics Shop',
#          'pluralName': 'Cosmetics Shops',
#          'shortName': 'Cosmetics',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/beauty_cosmetic_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4babaa1df964a52034be3ae3-27'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '572279ef498e59d0cebca562',
#        'name': 'American Prohibition Museum',
#        'location': {'address': '209 W Saint Julian St',
#         'lat': 32.0805587487151,
#         'lng': -81.09462350606918,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 32.0805587487151,
#           'lng': -81.09462350606918}],
#         'distance': 327,
#         'postalCode': '31401',
#         'cc': 'US',
#         'neighborhood': 'Historic District-North',
#         'city': 'Savannah',
#         'state': 'GA',
#         'country': 'United States',
#         'formattedAddress': ['209 W Saint Julian St',
#          'Savannah, GA 31401',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d181941735',
#          'name': 'Museum',
#          'pluralName': 'Museums',
#          'shortName': 'Museum',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/museum_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-572279ef498e59d0cebca562-28'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '582a784d88a1a04531401d90',
#        'name': 'Alley Cat Lounge',
#        'location': {'address': '207 W Broughton St (access from the lane)',
#         'lat': 32.079542873596885,
#         'lng': -81.09465397139586,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 32.079542873596885,
#           'lng': -81.09465397139586}],
#         'distance': 362,
#         'postalCode': '31401',
#         'cc': 'US',
#         'city': 'Savannah',
#         'state': 'GA',
#         'country': 'United States',
#         'formattedAddress': ['207 W Broughton St (access from the lane)',
#          'Savannah, GA 31401',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d121941735',
#          'name': 'Lounge',
#          'pluralName': 'Lounges',
#          'shortName': 'Lounge',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-582a784d88a1a04531401d90-29'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b6e0a31f964a5209ca52ce3',
#        'name': "Savannah's Candy Kitchen",
#        'location': {'address': '318 W Saint Julian St',
#         'crossStreet': 'at City Market',
#         'lat': 32.08097900006547,
#         'lng': -81.09528789672825,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 32.08097900006547,
#           'lng': -81.09528789672825},
#          {'label': '?', 'lat': 32.081126, 'lng': -81.095573}],
#         'distance': 387,
#         'postalCode': '31401',
#         'cc': 'US',
#         'city': 'Savannah',
#         'state': 'GA',
#         'country': 'United States',
#         'formattedAddress': ['318 W Saint Julian St (at City Market)',
#          'Savannah, GA 31401',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1d0941735',
#          'name': 'Dessert Shop',
#          'pluralName': 'Dessert Shops',
#          'shortName': 'Desserts',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/dessert_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b6e0a31f964a5209ca52ce3-30'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b61bf65f964a52049202ae3',
#        'name': 'Wright Square',
#        'location': {'address': 'Wright Square',
#         'crossStreet': 'State St',
#         'lat': 32.077915682055504,
#         'lng': -81.0922961908173,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 32.077915682055504,
#           'lng': -81.0922961908173}],
#         'distance': 351,
#         'postalCode': '31401',
#         'cc': 'US',
#         'city': 'Savannah',
#         'state': 'GA',
#         'country': 'United States',
#         'formattedAddress': ['Wright Square (State St)',
#          'Savannah, GA 31401',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d164941735',
#          'name': 'Plaza',
#          'pluralName': 'Plazas',
#          'shortName': 'Plaza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/plaza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b61bf65f964a52049202ae3-31'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b6e2940f964a520c2ae2ce3',
#        'name': 'Alligator Soul',
#        'location': {'address': '114 Barnard St',
#         'lat': 32.07901036854953,
#         'lng': -81.09432612362062,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 32.07901036854953,
#           'lng': -81.09432612362062},
#          {'label': '?', 'lat': 32.078985, 'lng': -81.094269}],
#         'distance': 365,
#         'postalCode': '31401',
#         'cc': 'US',
#         'city': 'Savannah',
#         'state': 'GA',
#         'country': 'United States',
#         'formattedAddress': ['114 Barnard St',
#          'Savannah, GA 31401',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d14f941735',
#          'name': 'Southern / Soul Food Restaurant',
#          'pluralName': 'Southern / Soul Food Restaurants',
#          'shortName': 'Southern / Soul',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/southern_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '61162667'}},
#       'referralId': 'e-0-4b6e2940f964a520c2ae2ce3-32'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '53add407498e8cd08328ee82',
#        'name': 'Pie Society City Market',
#        'location': {'address': '19 Jefferson St',
#         'crossStreet': 'West Bryan Street',
#         'lat': 32.08094132732409,
#         'lng': -81.09490480933981,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 32.08094132732409,
#           'lng': -81.09490480933981}],
#         'distance': 351,
#         'postalCode': '31401',
#         'cc': 'US',
#         'city': 'Savannah',
#         'state': 'GA',
#         'country': 'United States',
#         'formattedAddress': ['19 Jefferson St (West Bryan Street)',
#          'Savannah, GA 31401',
#          'United States']},
#        'categories': [{'id': '52e81612bcbc57f1066b7a0a',
#          'name': 'Pie Shop',
#          'pluralName': 'Pie Shops',
#          'shortName': 'Pie Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pieshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-53add407498e8cd08328ee82-33'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ba94930f964a520701b3ae3',
#        'name': 'City Market Savannah',
#        'location': {'address': '224 W Saint Julian St',
#         'crossStreet': 'at Barnard',
#         'lat': 32.080794,
#         'lng': -81.094961,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 32.080794,
#           'lng': -81.094961},
#          {'label': '?', 'lat': 32.080945, 'lng': -81.094408}],
#         'distance': 357,
#         'postalCode': '31401',
#         'cc': 'US',
#         'city': 'Savannah',
#         'state': 'GA',
#         'country': 'United States',
#         'formattedAddress': ['224 W Saint Julian St (at Barnard)',
#          'Savannah, GA 31401',
#          'United States']},
#        'categories': [{'id': '50be8ee891d4fa8dcc7199a7',
#          'name': 'Market',
#          'pluralName': 'Markets',
#          'shortName': 'Market',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/market_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ba94930f964a520701b3ae3-34'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5abe68ffd41bb7723cac2672',
#        'name': 'Maple Street Biscuit Company',
#        'location': {'address': '220 W Broughton St',
#         'lat': 32.079896999999995,
#         'lng': -81.09468199999999,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 32.079896999999995,
#           'lng': -81.09468199999999},
#          {'label': '?', 'lat': 32.079798, 'lng': -81.094804}],
#         'distance': 349,
#         'postalCode': '31401',
#         'cc': 'US',
#         'neighborhood': 'Historic District-North',
#         'city': 'Savannah',
#         'state': 'GA',
#         'country': 'United States',
#         'formattedAddress': ['220 W Broughton St',
#          'Savannah, GA 31401',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d14f941735',
#          'name': 'Southern / Soul Food Restaurant',
#          'pluralName': 'Southern / Soul Food Restaurants',
#          'shortName': 'Southern / Soul',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/southern_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5abe68ffd41bb7723cac2672-35'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4aef272ff964a5201ad621e3',
#        'name': "Zunzi's",
#        'location': {'address': '108 E York St',
#         'crossStreet': 'Drayton',
#         'lat': 32.07738661566027,
#         'lng': -81.09104510548039,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 32.07738661566027,
#           'lng': -81.09104510548039}],
#         'distance': 394,
#         'postalCode': '31401',
#         'cc': 'US',
#         'city': 'Savannah',
#         'state': 'GA',
#         'country': 'United States',
#         'formattedAddress': ['108 E York St (Drayton)',
#          'Savannah, GA 31401',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1c8941735',
#          'name': 'African Restaurant',
#          'pluralName': 'African Restaurants',
#          'shortName': 'African',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/african_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1401127',
#         'url': 'https://www.grubhub.com/restaurant/zunzis-takeout--catering-108-e-york-st-savannah/1401127?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1401127',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4aef272ff964a5201ad621e3-36'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b61c153f964a520b4202ae3',
#        'name': 'Telfair Square',
#        'location': {'address': 'Telfair Square',
#         'crossStreet': 'Barnard St.',
#         'lat': 32.0785156211238,
#         'lng': -81.0945725440979,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 32.0785156211238,
#           'lng': -81.0945725440979}],
#         'distance': 417,
#         'postalCode': '31401',
#         'cc': 'US',
#         'city': 'Savannah',
#         'state': 'GA',
#         'country': 'United States',
#         'formattedAddress': ['Telfair Square (Barnard St.)',
#          'Savannah, GA 31401',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d164941735',
# ...
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ad0d31ff964a52028da20e3-41'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '50269e64e4b0b57d71bbe8f6',
#        'name': 'Dick Blick Art Supply',
#        'location': {'address': '318 E Broughton St',
#         'lat': 32.07807523537594,
#         'lng': -81.08800625558473,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 32.07807523537594,
#           'lng': -81.08800625558473},
#          {'label': '?', 'lat': 32.077988, 'lng': -81.087952}],
#         'distance': 436,
#         'postalCode': '31401',
#         'cc': 'US',
#         'city': 'Savannah',
#         'state': 'GA',
#         'country': 'United States',
#         'formattedAddress': ['318 E Broughton St',
#          'Savannah, GA 31401',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d127951735',
#          'name': 'Arts & Crafts Store',
#          'pluralName': 'Arts & Crafts Stores',
#          'shortName': 'Arts & Crafts',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/artstore_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-50269e64e4b0b57d71bbe8f6-42'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '53722446498e983d14b583c5',
#        'name': 'The Collins Quarter',
#        'location': {'address': '151 Bull St',
#         'crossStreet': 'Oglethorpe Ave',
#         'lat': 32.07701773975055,
#         'lng': -81.09270156473592,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 32.07701773975055,
#           'lng': -81.09270156473592},
#          {'label': '?', 'lat': 32.077228, 'lng': -81.09292}],
#         'distance': 458,
#         'postalCode': '31401',
#         'cc': 'US',
#         'city': 'Savannah',
#         'state': 'GA',
#         'country': 'United States',
#         'formattedAddress': ['151 Bull St (Oglethorpe Ave)',
#          'Savannah, GA 31401',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d169941735',
#          'name': 'Australian Restaurant',
#          'pluralName': 'Australian Restaurants',
#          'shortName': 'Australian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/australian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-53722446498e983d14b583c5-43'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '531fc89011d2500619884472',
#        'name': 'Barrel House South',
#        'location': {'address': '125 W Congress St',
#         'lat': 32.08016042432702,
#         'lng': -81.09352733786467,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 32.08016042432702,
#           'lng': -81.09352733786467}],
#         'distance': 237,
#         'postalCode': '31401',
#         'cc': 'US',
#         'city': 'Savannah',
#         'state': 'GA',
#         'country': 'United States',
#         'formattedAddress': ['125 W Congress St',
#          'Savannah, GA 31401',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d116941735',
#          'name': 'Bar',
#          'pluralName': 'Bars',
#          'shortName': 'Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '120896086'}},
#       'referralId': 'e-0-531fc89011d2500619884472-44'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b6edc2bf964a520cdcd2ce3',
#        'name': 'Juliette Gordon Low Birthplace, National Historic Landmark',
#        'location': {'address': '10 E Oglethorpe Ave',
#         'crossStreet': 'at Bull Street',
#         'lat': 32.07702598095572,
#         'lng': -81.09258450899081,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 32.07702598095572,
#           'lng': -81.09258450899081},
#          {'label': '?', 'lat': 32.077013, 'lng': -81.092441}],
#         'distance': 454,
#         'postalCode': '31401',
#         'cc': 'US',
#         'city': 'Savannah',
#         'state': 'GA',
#         'country': 'United States',
#         'formattedAddress': ['10 E Oglethorpe Ave (at Bull Street)',
#          'Savannah, GA 31401',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d181941735',
#          'name': 'Museum',
#          'pluralName': 'Museums',
#          'shortName': 'Museum',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/museum_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '38098077'}},
#       'referralId': 'e-0-4b6edc2bf964a520cdcd2ce3-45'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d18cf05302da1cd4273c593',
#        'name': 'Sweet Water Spa',
#        'location': {'address': '311 W.Broughton st Floor 2',
#         'crossStreet': 'Jefferson Street',
#         'lat': 32.0797883199812,
#         'lng': -81.09579563140869,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 32.0797883199812,
#           'lng': -81.09579563140869}],
#         'distance': 453,
#         'postalCode': '31401',
#         'cc': 'US',
#         'city': 'Savannah',
#         'state': 'GA',
#         'country': 'United States',
#         'formattedAddress': ['311 W.Broughton st Floor 2 (Jefferson Street)',
#          'Savannah, GA 31401',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1ed941735',
#          'name': 'Spa',
#          'pluralName': 'Spas',
#          'shortName': 'Spa',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/spa_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '57854710'}},
#       'referralId': 'e-0-4d18cf05302da1cd4273c593-46'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5bdb14611c675b0039fbecca',
#        'name': 'The Grey Market',
#        'location': {'address': '109 Jefferson St',
#         'lat': 32.079313,
#         'lng': -81.095704,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 32.079313,
#           'lng': -81.095704},
#          {'label': '?', 'lat': 32.079333, 'lng': -81.095594}],
#         'distance': 463,
#         'postalCode': '31401',
#         'cc': 'US',
#         'city': 'Savannah',
#         'state': 'GA',
#         'country': 'United States',
#         'formattedAddress': ['109 Jefferson St',
#          'Savannah, GA 31401',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d146941735',
#          'name': 'Deli / Bodega',
#          'pluralName': 'Delis / Bodegas',
#          'shortName': 'Deli / Bodega',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5bdb14611c675b0039fbecca-47'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cc3537c1e596dcbcac7c967',
#        'name': 'The Peanut Shop Of Savannah',
#        'location': {'address': '407 E River St',
#         'lat': 32.080483917970916,
#         'lng': -81.08645398578996,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 32.080483917970916,
#           'lng': -81.08645398578996},
#          {'label': '?', 'lat': 32.080493, 'lng': -81.08643}],
#         'distance': 448,
#         'postalCode': '31401',
#         'cc': 'US',
#         'city': 'Savannah',
#         'state': 'GA',
#         'country': 'United States',
#         'formattedAddress': ['407 E River St',
#          'Savannah, GA 31401',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1f5941735',
#          'name': 'Gourmet Shop',
#          'pluralName': 'Gourmet Shops',
#          'shortName': 'Gourmet',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_gourmet_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4cc3537c1e596dcbcac7c967-48'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '573f3b84498eae6c31de8204',
#        'name': 'Cup to Cup Cafe',
#        'location': {'lat': 32.07666648520378,
#         'lng': -81.09031801132802,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 32.07666648520378,
#           'lng': -81.09031801132802}],
#         'distance': 481,
#         'cc': 'US',
#         'city': 'Savannah',
#         'state': 'GA',
#         'country': 'United States',
#         'formattedAddress': ['Savannah, GA', 'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-573f3b84498eae6c31de8204-49'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ba90861f964a5204e053ae3',
#        'name': 'River Street Market',
#        'location': {'address': '502 E River St',
#         'lat': 32.080510575494486,
#         'lng': -81.08610484651051,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 32.080510575494486,
#           'lng': -81.08610484651051}],
#         'distance': 480,
#         'postalCode': '31401',
#         'cc': 'US',
#         'city': 'Savannah',
#         'state': 'GA',
#         'country': 'United States',
#         'formattedAddress': ['502 E River St',
#          'Savannah, GA 31401',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1fd941735',
#          'name': 'Shopping Mall',
#          'pluralName': 'Shopping Malls',
#          'shortName': 'Mall',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/mall_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ba90861f964a5204e053ae3-50'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c013691783720a19144c62e',
#        'name': 'Vietnam Memorial',
#        'location': {'lat': 32.079896583589196,
#         'lng': -81.08629797119588,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 32.079896583589196,
#           'lng': -81.08629797119588}],
#         'distance': 474,
#         'postalCode': '31401',
#         'cc': 'US',
#         'city': 'Savannah',
#         'state': 'GA',
#         'country': 'United States',
#         'formattedAddress': ['Savannah, GA 31401', 'United States']},
#        'categories': [{'id': '4bf58dd8d48988d12d941735',
#          'name': 'Monument / Landmark',
#          'pluralName': 'Monuments / Landmarks',
#          'shortName': 'Landmark',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/government_monument_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c013691783720a19144c62e-51'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b92739df964a52090fa33e3',
#        'name': "Savannah's Irish and Robert Emmet Park",
#        'location': {'address': 'E Bay Ave',
#         'crossStreet': 'Habersham Ave',
#         'lat': 32.07992643969387,
#         'lng': -81.08646843342267,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 32.07992643969387,
#           'lng': -81.08646843342267}],
#         'distance': 457,
#         'cc': 'US',
#         'city': 'Savannah',
#         'state': 'GA',
#         'country': 'United States',
#         'formattedAddress': ['E Bay Ave (Habersham Ave)',
#          'Savannah, GA',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d163941735',
#          'name': 'Park',
#          'pluralName': 'Parks',
#          'shortName': 'Park',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b92739df964a52090fa33e3-52'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b73420bf964a520bca42de3',
#        'name': "One-Eyed Lizzy's",
#        'location': {'address': '417 E River St',
#         'lat': 32.08046035215639,
#         'lng': -81.08598233592946,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 32.08046035215639,
#           'lng': -81.08598233592946}],
#         'distance': 492,
#         'postalCode': '31401',
#         'cc': 'US',
#         'city': 'Savannah',
#         'state': 'GA',
#         'country': 'United States',
#         'formattedAddress': ['417 E River St',
#          'Savannah, GA 31401',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1ce941735',
#          'name': 'Seafood Restaurant',
#          'pluralName': 'Seafood Restaurants',
#          'shortName': 'Seafood',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/seafood_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b73420bf964a520bca42de3-53'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b984681f964a520ed3835e3',
#        'name': 'Oyster Bar',
#        'location': {'address': '411 E River St',
#         'lat': 32.080495658499764,
#         'lng': -81.08603474158772,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 32.080495658499764,
#           'lng': -81.08603474158772},
#          {'label': '?', 'lat': 32.08051, 'lng': -81.086492}],
#         'distance': 487,
#         'postalCode': '31401',
#         'cc': 'US',
#         'city': 'Savannah',
#         'state': 'GA',
#         'country': 'United States',
#         'formattedAddress': ['411 E River St',
#          'Savannah, GA 31401',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1ce941735',
#          'name': 'Seafood Restaurant',
#          'pluralName': 'Seafood Restaurants',
#          'shortName': 'Seafood',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/seafood_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b984681f964a520ed3835e3-54'}]}]}}

# %%
# create map of Miami using latitude and longitude values
map_miami = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, borough, neighborhood in zip(neighborhoods['Latitude'], neighborhoods['Longitude'], neighborhoods['Borough'], neighborhoods['Neighborhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_miami)  
    
#map_miami
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-d98a4b9dfb79> in <module>
#       1 # create map of Miami using latitude and longitude values
# ----> 2 map_miami = folium.Map(location=[latitude, longitude], zoom_start=10)
#       3
#       4 # add markers to map
#       5 for lat, lng, borough, neighborhood in zip(neighborhoods['Latitude'], neighborhoods['Longitude'], neighborhoods['Borough'], neighborhoods['Neighborhood']):
#
# NameError: name 'folium' is not defined

# %%
#Create a handle, page, to handle the contents of the website
#page = requests.get(url)
URL = 'https://en.wikipedia.org/wiki/List_of_neighborhoods_in_Miami'
page = requests.get(URL)

# %%
import lxml.html as lh
#Store the contents of the website under doc
doc = lh.fromstring(page.content)

# %%
#Parse data that are stored between <tr>..</tr> of HTML
tr_elements = doc.xpath('//tr')

# %%
[len(T) for T in tr_elements[:12]]
# Out:
# [6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6]

# %%
tr_elements = doc.xpath('//tr')
#Create empty list
col=[]
i=0   
    #For each row, store each first element (header) and an empty list
for t in tr_elements[0]:
    i+=1
    name=t.text_content()

    print (i,name)
    col.append((name,[]))
# Out:
# 1 Neighborhood
# 2 Demonym
# 3 Population2010
# 4 Population/Km²
# 5 Sub-neighborhoods
# 6 Coordinates

# %%
#Since out first row is the header, data is stored on the second row onwards
for j in range(1,len(tr_elements)):
    #T is our j'th row
    T=tr_elements[j]
    
    #If row is not of size 3, the //tr data is not from our table 
    if len(T)!=6:
        break
    
    #i is the index of our column
    i=0
    
    #Iterate through each element of the row
    for t in T.iterchildren():
        data=t.text_content() 
        #Check if row is empty
        if i>0:
        #Convert any numerical value to integers
            try:
                data=int(data)
            except:
                pass
        #Append the data to the empty list of the i'th column
        col[i][1].append(data)
        #Increment i for the next column
        i+=1

# %%
[len(C) for (title,C) in col]
# Out:
# [26, 26, 26, 26, 26, 26]

# %%
Dict={title:column for (title,column) in col}
df=pd.DataFrame(Dict)
df.head()
# Out:
#                     Neighborhood      Demonym Population2010 Population/Km²  \
# 0                     Allapattah                      54,289          4,401
# 1  Arts & Entertainment District                      11,033          7,948
# 2                       Brickell  Brickellite         31,759         14,541
# 3                    Buena Vista                       9,058          3,540
# 4                  Coconut Grove      Grovite         20,076          3,091
#
#                                    Sub-neighborhoods     Coordinates\n
# 0                                                     25.815,-80.224\n
# 1                                                     25.799,-80.190\n
# 2                                      West Brickell  25.758,-80.193\n
# 3  Buena Vista East Historic District and Design ...  25.813,-80.192\n
# 4  Center Grove, Northeast Coconut Grove, Southwe...  25.712,-80.257\n

# %%
df2= df.replace(r'\n',  '', regex=True)
df2.head()
# Out:
#                     Neighborhood      Demonym Population2010 Population/Km²  \
# 0                     Allapattah                      54,289          4,401
# 1  Arts & Entertainment District                      11,033          7,948
# 2                       Brickell  Brickellite         31,759         14,541
# 3                    Buena Vista                       9,058          3,540
# 4                  Coconut Grove      Grovite         20,076          3,091
#
#                                    Sub-neighborhoods   Coordinates\n
# 0                                                     25.815,-80.224
# 1                                                     25.799,-80.190
# 2                                      West Brickell  25.758,-80.193
# 3  Buena Vista East Historic District and Design ...  25.813,-80.192
# 4  Center Grove, Northeast Coconut Grove, Southwe...  25.712,-80.257

# %%
df2.columns = df.columns.str.replace("\n", "")
list(df2)
# Out:
# ['Neighborhood',
#  'Demonym',
#  'Population2010',
#  'Population/Km²',
#  'Sub-neighborhoods',
#  'Coordinates']

# %%
# new data frame with split value columns 
new = df2["Coordinates"].str.split(",", n = 1, expand = True) 
new.head()
# Out:
#         0        1
# 0  25.815  -80.224
# 1  25.799  -80.190
# 2  25.758  -80.193
# 3  25.813  -80.192
# 4  25.712  -80.257

# %%
# making separate first name column from new data frame 
df2["Latitude"]= new[0] 
  
# making separate last name column from new data frame 
df2["Longitude"]= new[1] 

df2.head(20)
# Out:
#                      Neighborhood      Demonym            Population2010  \
# 0                      Allapattah                                 54,289
# 1   Arts & Entertainment District                                 11,033
# 2                        Brickell  Brickellite                    31,759
# 3                     Buena Vista                                  9,058
# 4                   Coconut Grove      Grovite                    20,076
# 5                       Coral Way                                 35,062
# 6                 Design District                                  3,573
# 7                        Downtown   Downtowner  71,000 (13,635 CBD only)
# 8                       Edgewater                                 15,005
# 9                         Flagami                                 50,834
# 10              Grapeland Heights                                 14,004
# 11                Health District                                  2,705
# 12                   Liberty City                                 19,725
# 13                   Little Haiti                                 29,760
# 14                  Little Havana                                 76,163
# 15                    Lummus Park                                  3,027
# 16                        Midtown    Midtowner                         -
# 17                       Overtown       Towner                     6,736
# 18                      Park West                                  4,655
# 19                      The Roads                                  7,327
#
#    Population/Km²                                  Sub-neighborhoods  \
# 0           4,401
# 1           7,948
# 2          14,541                                      West Brickell
# 3           3,540  Buena Vista East Historic District and Design ...
# 4           3,091  Center Grove, Northeast Coconut Grove, Southwe...
# 5           4,496  Coral Gate, Golden Pines, Shenandoah, Historic...
# 6           3,623
# 7          10,613  Brickell, Central Business District (CBD), Dow...
# 8           6,675
# 9           5,665           Alameda, Grapeland Heights, and Fairlawn
# 10          4,130
# 11          2,148
# 12          3,733
# 13          3,840                      Lemon City (aka Little River)
# 14          8,423  Riverside and South River Drive Historic District
# 15          3,680
# 16              -                              Edgewater and Wynwood
# 17          3,405                                      Spring Garden
# 18          3,635
# 19          4,899
#
#        Coordinates Latitude Longitude
# 0   25.815,-80.224   25.815   -80.224
# 1   25.799,-80.190   25.799   -80.190
# 2   25.758,-80.193   25.758   -80.193
# 3   25.813,-80.192   25.813   -80.192
# 4   25.712,-80.257   25.712   -80.257
# 5   25.750,-80.283   25.750   -80.283
# 6   25.813,-80.193   25.813   -80.193
# 7   25.774,-80.193   25.774   -80.193
# 8   25.802,-80.190   25.802   -80.190
# 9   25.762,-80.316   25.762   -80.316
# 10  25.792,-80.258   25.792   -80.258
# 11                               None
# 12  25.832,-80.225   25.832   -80.225
# 13  25.824,-80.191   25.824   -80.191
# 14  25.773,-80.215   25.773   -80.215
# 15  25.777,-80.201   25.777   -80.201
# 16  25.807,-80.193   25.807   -80.193
# 17  25.787,-80.201   25.787   -80.201
# 18  25.785,-80.193   25.785   -80.193
# 19  25.756,-80.207   25.756   -80.207

# %%
LH_data = df2[df2['Neighborhood'] == 'Little Havana'].reset_index(drop=True)
LH_data.head()
# Out:
#     Neighborhood Demonym Population2010 Population/Km²  \
# 0  Little Havana                 76,163          8,423
#
#                                    Sub-neighborhoods     Coordinates Latitude  \
# 0  Riverside and South River Drive Historic District  25.773,-80.215   25.773
#
#   Longitude
# 0   -80.215

# %%
address = 'Little Havana, FL'

geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Little Havana are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Little Havana are 25.7681503, -80.2334686.

# %%
LH_data.loc[0, 'Neighborhood']
# Out:
# 'Little Havana'

# %%
neighborhood_latitude = LH_data.loc[0, 'Latitude'] # neighborhood latitude value
neighborhood_longitude = LH_data.loc[0, 'Longitude'] # neighborhood longitude value

neighborhood_name = LH_data.loc[0, 'Neighborhood'] # neighborhood name

print('Latitude and longitude values of {} are {}, {}.'.format(neighborhood_name, 
                                                               neighborhood_latitude, 
                                                               neighborhood_longitude))
# Out:
# Latitude and longitude values of Little Havana are 25.773, -80.215.

# %%
LIMIT = 100 # limit of number of venues returned by Foursquare API

radius = 500 # define radius

# create URL
url2 = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    neighborhood_latitude, 
    neighborhood_longitude, 
    radius, 
    LIMIT)
url2 # display URL
# Out:
# 'https://api.foursquare.com/v2/venues/explore?&client_id=KTOGVYYQUEWMCLZYN3EHY3W1FJ2EUDJ1FIXZKSXQCWBXNQJA&client_secret=01RRALCQSNM3UZKYRWZYBNMJL5O5TBFCCBRVKYI4XUA0MSWW&v=20180604&ll=25.773,-80.215&radius=500&limit=100'

# %%
results = requests.get(url2).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5ea11d3dc546f3001c01032a'},
#  'response': {'headerLocation': 'Little Havana',
#   'headerFullLocation': 'Little Havana, Miami',
#   'headerLocationGranularity': 'neighborhood',
#   'totalResults': 7,
#   'suggestedBounds': {'ne': {'lat': 25.777500004500006,
#     'lng': -80.2100122332913},
#    'sw': {'lat': 25.768499995499994, 'lng': -80.21998776670871}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c017871f7ab0f47e42e16b6',
#        'name': 'Pinolandia',
#        'location': {'address': '119 NW 12th Ave',
#         'lat': 25.774786961412257,
#         'lng': -80.21464073279162,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 25.774786961412257,
#           'lng': -80.21464073279162}],
#         'distance': 202,
#         'postalCode': '33128',
#         'cc': 'US',
#         'city': 'Miami',
#         'state': 'FL',
#         'country': 'United States',
#         'formattedAddress': ['119 NW 12th Ave',
#          'Miami, FL 33128',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1be941735',
#          'name': 'Latin American Restaurant',
#          'pluralName': 'Latin American Restaurants',
#          'shortName': 'Latin American',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/latinamerican_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c017871f7ab0f47e42e16b6-0'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ce83262b9975481d613fb44',
#        'name': "Sedano's",
#        'location': {'address': '1263 W Flagler St',
#         'lat': 25.774067190329124,
#         'lng': -80.21579934731425,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 25.774067190329124,
#           'lng': -80.21579934731425}],
#         'distance': 143,
#         'postalCode': '33135',
#         'cc': 'US',
#         'city': 'Miami',
#         'state': 'FL',
#         'country': 'United States',
#         'formattedAddress': ['1263 W Flagler St',
#          'Miami, FL 33135',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d118951735',
#          'name': 'Grocery Store',
#          'pluralName': 'Grocery Stores',
#          'shortName': 'Grocery Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ce83262b9975481d613fb44-1'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c16becb96040f47225973a5',
#        'name': 'Walgreens',
#        'location': {'address': '1201 SW 1st St',
#         'lat': 25.7729397,
#         'lng': -80.2149856,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 25.7729397,
#           'lng': -80.2149856},
#          {'label': '?', 'lat': 25.772665, 'lng': -80.214993}],
#         'distance': 6,
#         'postalCode': '33135',
#         'cc': 'US',
#         'city': 'Miami',
#         'state': 'FL',
#         'country': 'United States',
#         'formattedAddress': ['1201 SW 1st St',
#          'Miami, FL 33135',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d10f951735',
#          'name': 'Pharmacy',
#          'pluralName': 'Pharmacies',
#          'shortName': 'Pharmacy',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pharmacy_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c16becb96040f47225973a5-2'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d347d7b2c76a143d16785c7',
#        'name': 'El Palacio De Los Jugos',
#        'location': {'address': '1101 W Flagler St',
#         'lat': 25.77381,
#         'lng': -80.21315799999999,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 25.77381,
#           'lng': -80.21315799999999},
#          {'label': '?', 'lat': 25.773694, 'lng': -80.213192}],
#         'distance': 205,
#         'postalCode': '33130',
#         'cc': 'US',
#         'city': 'Miami',
#         'state': 'FL',
#         'country': 'United States',
#         'formattedAddress': ['1101 W Flagler St',
#          'Miami, FL 33130',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1be941735',
#          'name': 'Latin American Restaurant',
#          'pluralName': 'Latin American Restaurants',
#          'shortName': 'Latin American',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/latinamerican_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d347d7b2c76a143d16785c7-3'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '54f0a7b6498edb39ef2c1f9c',
#        'name': 'Viva México',
#        'location': {'address': '542 SW 12th Ave',
#         'lat': 25.76858063139083,
#         'lng': -80.21461378265897,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 25.76858063139083,
#           'lng': -80.21461378265897}],
#         'distance': 493,
#         'postalCode': '33130',
#         'cc': 'US',
#         'city': 'Miami',
#         'state': 'FL',
#         'country': 'United States',
#         'formattedAddress': ['542 SW 12th Ave',
#          'Miami, FL 33130',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1c1941735',
#          'name': 'Mexican Restaurant',
#          'pluralName': 'Mexican Restaurants',
#          'shortName': 'Mexican',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mexican_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-54f0a7b6498edb39ef2c1f9c-4'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '57a3679fcd107b49b082ff5c',
#        'name': 'Dollar Tree',
#        'location': {'address': '1043 W Flagler St',
#         'lat': 25.773894,
#         'lng': -80.21252,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 25.773894,
#           'lng': -80.21252},
#          {'label': '?', 'lat': 25.77371, 'lng': -80.21223}],
#         'distance': 267,
#         'postalCode': '33130',
#         'cc': 'US',
#         'city': 'Miami',
#         'state': 'FL',
#         'country': 'United States',
#         'formattedAddress': ['1043 W Flagler St',
#          'Miami, FL 33130',
#          'United States']},
#        'categories': [{'id': '52dea92d3cf9994f4e043dbb',
#          'name': 'Discount Store',
#          'pluralName': 'Discount Stores',
#          'shortName': 'Discount Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/discountstore_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-57a3679fcd107b49b082ff5c-5'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d1a1437731976ebc46c09dc',
#        'name': 'Foot Locker',
#        'location': {'address': '1071 W Flagler St',
#         'lat': 25.773774168382317,
#         'lng': -80.21282583475113,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 25.773774168382317,
#           'lng': -80.21282583475113},
#          {'label': '?', 'lat': 25.773697, 'lng': -80.212798}],
#         'distance': 234,
#         'postalCode': '33130',
#         'cc': 'US',
#         'city': 'Miami',
#         'state': 'FL',
#         'country': 'United States',
#         'formattedAddress': ['1071 W Flagler St',
#          'Miami, FL 33130',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d107951735',
#          'name': 'Shoe Store',
#          'pluralName': 'Shoe Stores',
#          'shortName': 'Shoes',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_shoestore_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d1a1437731976ebc46c09dc-6'}]}]}}

# %%
# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %%
venues = results['response']['groups'][0]['items']
    
nearby_venues = json_normalize(venues) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
nearby_venues =nearby_venues.loc[:, filtered_columns]

# filter the category for each row
nearby_venues['venue.categories'] = nearby_venues.apply(get_category_type, axis=1)

# clean columns
nearby_venues.columns = [col.split(".")[-1] for col in nearby_venues.columns]

nearby_venues.head()
# Out:
#                       name                 categories        lat        lng
# 0               Pinolandia  Latin American Restaurant  25.774787 -80.214641
# 1                 Sedano's              Grocery Store  25.774067 -80.215799
# 2                Walgreens                   Pharmacy  25.772940 -80.214986
# 3  El Palacio De Los Jugos  Latin American Restaurant  25.773810 -80.213158
# 4              Viva México         Mexican Restaurant  25.768581 -80.214614

# %%
print('{} venues were returned by Foursquare.'.format(nearby_venues.shape[0]))
# Out:
# 7 venues were returned by Foursquare.

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
# type your answer here

LH_venues = getNearbyVenues(names=LH_data['Neighborhood'],
                                   latitudes=LH_data['Latitude'],
                                   longitudes=LH_data['Longitude']
                                  )
# Out:
# Little Havana

# %%
print(LH_venues.shape)
LH_venues.head()
# Out:
# (7, 7)
#     Neighborhood Neighborhood Latitude Neighborhood Longitude  \
# 0  Little Havana                25.773                -80.215
# 1  Little Havana                25.773                -80.215
# 2  Little Havana                25.773                -80.215
# 3  Little Havana                25.773                -80.215
# 4  Little Havana                25.773                -80.215
#
#                      Venue  Venue Latitude  Venue Longitude  \
# 0               Pinolandia       25.774787       -80.214641
# 1                 Sedano's       25.774067       -80.215799
# 2                Walgreens       25.772940       -80.214986
# 3  El Palacio De Los Jugos       25.773810       -80.213158
# 4              Viva México       25.768581       -80.214614
#
#               Venue Category
# 0  Latin American Restaurant
# 1              Grocery Store
# 2                   Pharmacy
# 3  Latin American Restaurant
# 4         Mexican Restaurant

# %%
address = 'New York City, NY'

geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of New York City are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of New York City are 40.7127281, -74.0060152.
